# %%
#Variables in python

first_name= 'Pratibha'
last_name= 'Gunwannt'
country= 'India'
city= 'Delhi'
age= 24
is_married= False
skills= ['HTML', 'CSS', 'EXCEL', 'JS', 'Python']
person_info= {'firstname': 'Pratibha',
    'lastname': 'Gunwannt',
    'country': 'India',
    'city': 'Delhi'}

# %%
print(first_name)
# Out:
# Pratibha

# %%
print(skills[3])
# Out:
# JS

# %%
print(first_name)
# Out:
# Pratibha

# %%
print(is_married)
# Out:
# False

# %%
print("First Name:" ,first_name)
print("First name length:" ,len(first_name))
print("Last name:" ,last_name)
print("Last name length:" ,len(last_name))
print("Country:" ,country)
print("city:" ,city)
print("Age:" ,age)
print("Married:" ,is_married)
print("Skills:" ,skills)
print("Personal information:" ,person_info)
# Out:
# First Name: Pratibha
# First name length: 8
# Last name: Gunwannt
# Last name length: 8
# Country: India
# city: Delhi
# Age: 24
# Married: False
# Skills: ['HTML', 'CSS', 'EXCEL', 'JS', 'Python']
# Personal information: {'firstname': 'Pratibha', 'lastname': 'Gunwannt', 'country': 'India', 'city': 'Delhi'}

# %%
#declaring multiple variables in one line

firstname, lastname, country, age, is_married= "Pratibha", "Gunwannt", "India", 24, False
print(firstname, lastname, country, age, is_married)
print("Name:" ,firstname, lastname)
print("Country:" ,country)
print("Age:" ,age)
print("Married:" ,is_married)
# Out:
# Pratibha Gunwannt India 24 False
# Name: Pratibha Gunwannt
# Country: India
# Age: 24
# Married: False

# %%
#Arithmetic Operations
#Integers
print("Addition:" ,1+2)
print("Division:" ,1/2)
print("Division:" ,7/2)
print("Remainder:" ,7//2)
print("Exponential:" ,3**2)
print("Modulus:" ,3%2)  #provides remainder
# Out:
# Addition: 3
# Division: 0.5
# Division: 3.5
# Remainder: 3
# Exponential: 9
# Modulus: 1

# %%
#floating numbers
print("Floating numbers, PI" , 3.14)
print("Gravity:" ,9.81)
# Out:
# Floating numbers, PI 3.14
# Gravity: 9.81

# %%
#complex numbers
print("complex numbers:" ,1+2j)
print("multiplying complex numbers:" ,(1+2j)*(1-2j))
# Out:
# complex numbers: (1+2j)
# multiplying complex numbers: (5+0j)

# %%
#Declaring a variable at the begining
a=3 #a is a variable and 3 is an integer data type
b=5 #b is a variable and 5 is an integer data type

#Now performing arithmetic operations
total= a+b
add= a+b
diff= a-b
product= a*b
division= a/b
print(total,add)
# Out:
# 8 8
