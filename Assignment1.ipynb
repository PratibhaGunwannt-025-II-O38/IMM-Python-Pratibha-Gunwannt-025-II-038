# %%
print('Day 2: IMM BUSINESS SCHOOL PYTHON PROGRAMMING')
# Out:
# Day 2: IMM BUSINESS SCHOOL PYTHON PROGRAMMING

# %%
firstname= 'Pratibha'
lastname= 'Gunwannt'
fullname= 'Pratibha Gunwannt'
country= 'India'
city= 'Delhi'
age= 24
year= 2026
is_married= False
is_true= True
is_light_on= 'yes'

# %%
print(firstname, lastname, country, city, age, is_married)
# Out:
# Pratibha Gunwannt India Delhi 24 False

# %%
print(type('Pratibha'))
print(type('Gunwannt'))
print(type('Pratibha Gunwannt'))
print(type('India'))
print(type('Delhi'))
print(type(24))
print(type(2026))
print(type(False))
print(type(True))
print(type( 'yes'))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>

# %%
print(len(firstname))
# Out:
# 8

# %%
print('First name length:' ,len(firstname))
print('Last name length:' ,len(lastname))
# Out:
# First name length: 8
# Last name length: 8

# %%
a=5
b=4
total= a+b
difference= b-a
product= b*a
division= a/b
remainder= b%a
variable_exp= a**b
floor_division= a//b
print(total, difference, product, division, remainder, variable_exp, floor_division)
# Out:
# 9 -1 20 1.25 4 625 1

# %%
#radius of circle= 30m, area of circle=3.14*radius^2, circumferemce of circle= 2*3.1*radius
a=30 
area_of_circle= 3.14*a**2
circum_of_circle= 2*3.14*a
print(area_of_circle)
print(circum_of_circle)
# Out:
# 2826.0
# 188.4

# %%
print( firstname, lastname, country, age)
# Out:
# Pratibha Gunwannt India 24

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
